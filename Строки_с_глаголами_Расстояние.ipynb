# %% [markdown]
# <a href="https://colab.research.google.com/github/let-cel/demo/blob/main/%D0%A1%D1%82%D1%80%D0%BE%D0%BA%D0%B8_%D1%81_%D0%B3%D0%BB%D0%B0%D0%B3%D0%BE%D0%BB%D0%B0%D0%BC%D0%B8_%D0%A0%D0%B0%D1%81%D1%81%D1%82%D0%BE%D1%8F%D0%BD%D0%B8%D0%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('/content/odyss_verb_new.csv')
df
# Out:
#       Unnamed: 0  book  line_nr  \
# 0              1     1        1
# 1              2     1        3
# 2              3     1        4
# 3              4     1        6
# 4              5     1        9
# ...          ...   ...      ...
# 8724        8725    24      541
# 8725        8726    24      543
# 8726        8727    24      544
# 8727        8728    24      545
# 8728        8729    24      548
#
#                                                pos_line  row_num
# 0     noun pronoun verb proper adjective pronoun adv...        1
# 1     adjective particle noun verb noun conjunction ...        3
# 2     adjective particle pronoun particle prepositio...        4
# 3       adverb particle pronoun noun verb verb particle        6
# 4     verb particle article pronoun verb adjective noun        9
# ...                                                 ...      ...
# 8724            particle adverb proper verb noun proper    12100
# ...

# %%
row = df['row_num']

differences = [row[i] - row[i - 1] for i in range (1, len(row))]

average = sum(differences) / len(differences)
round(average, 2)
# Out:
# 1.39

# %%
df2 = pd.read_csv('/content/iliad_verb.csv')
df2
# Out:
#        Unnamed: 0  book  line_nr  \
# 0               1     1        1
# 1               2     1        4
# 2               3     1        5
# 3               4     1        6
# 4               5     1        8
# ...           ...   ...      ...
# 11111       11112    24      799
# 11112       11113    24      800
# 11113       11114    24      801
# 11114       11115    24      802
# 11115       11116    24      804
#
#                                                 pos_line  row_num
# 0                           noun verb noun proper proper        1
# 1                   noun pronoun particle noun verb noun        4
# 2      noun particle adjective proper particle verb noun        5
# 3      preposition pronoun particle article adjective...        6
# 4      pronoun particle particle pronoun noun noun ve...        8
# ...                                                  ...      ...
# 11111  adverb particle adjective verb preposition par...    15677
# ...

# %%
row2 = df2['row_num']

differences2 = [row2[i] - row2[i - 1] for i in range (1, len(row2))]

average2 = sum(differences2) / len(differences2)
round(average2, 2)
# Out:
# 1.41

# %%
df3 = pd.read_csv('/content/argo_verb.csv')
df3
# Out:
#       Unnamed: 0 title    line  \
# 0              1  Argo     1_4
# 1              2  Argo     1_5
# 2              3  Argo     1_6
# 3              4  Argo     1_8
# 4              5  Argo     1_9
# ...          ...   ...     ...
# 3614        3615  Argo  4_1766
# 3615        3616  Argo  4_1768
# 3616        3617  Argo  4_1772
# 3617        3618  Argo  4_1775
# 3618        3619  Argo  4_1776
#
#                                                pos_line  row_num
# 0      adjective preposition noun adjective verb proper        4
# 1     adjective particle proper adjective verb conju...        5
# 2     adjective verb adjective pronoun noun pronoun ...        6
# 3     adjective particle adverb verb adjective prepo...        8
# 4           adjective noun verb preposition noun proper        9
# ...                                                 ...      ...
# 3614   pronoun particle verb verb preposition noun verb     5818
# ...

# %%
row3 = df3['row_num']

differences3 = [row3[i] - row3[i - 1] for i in range (1, len(row3))]

average3 = sum(differences3) / len(differences3)
round(average3, 2)
# Out:
# 1.61
